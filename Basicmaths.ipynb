# %%
print("wasim")
# Out:
# wasim

# %%
n = int(input("Enter the number:"))
factors = []

for i in range(1, int(n**0.5)+1):
    if n % i == 0:
        print(i)
        factors.append(i)
    elif n//i != i:
        print(n//i)
        factors.append(n//i)
    

print(factors)
# Out:
# 1
# 2
# 3
# 4
# 7
# 6
# [1, 2, 3, 4, 7, 6]

# %%
n1 = int(input("Enter the number:"))
n2 = 
gcd = 1

for i in range(1, min(n1,n2)+1):
    if (n1 % i == 0) and (n2 % i == 0):
        gdc = i
        print(gcd)
    break
# Out:
#   Cell In[1], line 2
#     n2 = ¸¸¸
#          ^
# SyntaxError: invalid character '¸' (U+00B8)

# %%
a = int(input("Enter the number:"))
b = int(input("Enter the number:"))

while a > 0 and b > 0:
    if a > 0 a = a%b
